# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinx03/AI_photoBooth/blob/main/Al_Photobooth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.11.11

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/drive/MyDrive/AI_photoBooth/datasets/data.yaml' epochs=50 imgsz=640 plots=True
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 69.1MB/s]
# New https://pypi.org/project/ultralytics/8.3.78 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/val_batch0_pred.jpg', width=600)
